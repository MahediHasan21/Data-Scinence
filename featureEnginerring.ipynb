# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
x=df.drop('Profit',axis=1)

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y=df['Profit']

# %%
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %%
x1=x.copy()

# %%
from sklearn.preprocessing import MinMaxScaler
scal=MinMaxScaler()
minMaxScal=scal.fit(x[['Administration','Marketing Spend','Transport']])
minMaxScal
# Out:
# MinMaxScaler()

# %%
x[['Administration','Marketing Spend','Transport']]=scal.transform(x[['Administration','Marketing Spend','Transport']])

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.651744   1.000000    Dhaka
# 1         0.983359        0.761972   0.940893      Ctg
# 2         0.927985        0.379579   0.864664  Rangpur
# 3         0.873136        0.512998   0.812235    Dhaka
# 4         0.859438        0.305328   0.776136  Rangpur

# %%
x2=df.copy()

# %%
x3=df.copy()
x4=df.copy()
x5=df.copy()

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
for col in x2.columns:
    if x2[col].dtype=='float64':
        x2[[col]]=ss.fit_transform(x2[[col]])
    else:
        continue

# %%
x2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913        0.560753   2.165287    Dhaka  2.011203
# 1         1.955860        1.082807   1.929843      Ctg  1.999430
# 2         1.754364       -0.728257   1.626191  Rangpur  1.980842
# 3         1.554784       -0.096365   1.417348    Dhaka  1.776627
# 4         1.504937       -1.079919   1.273550  Rangpur  1.357740

# %%
from sklearn.preprocessing import FunctionTransformer
ft= FunctionTransformer(np.log1p)

# %%
for col in x3.columns:
    if x3[col].dtype=='float64':
        x3[col]=ft.fit_transform(x3[[col]])
    else:
        continue

# %%
x3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        11.648545       11.826997  13.064279    Dhaka  12.166619
# 1        11.999040       11.927539  13.003354      Ctg  12.164172
# 2        11.941081       11.524326  12.918864  Rangpur  12.160298
# 3        11.880158       11.684126  12.856314    Dhaka  12.116711
# 4        11.864345       11.422922  12.810851  Rangpur  12.020881

# %%
from sklearn.preprocessing import RobustScaler
rs=RobustScaler()

# %%
for col in x4.columns:
    if x4[col].dtype=='float64':
        x4[[col]]=rs.fit_transform(x4[[col]])
    else:
        continue

# %%
x4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.672530        0.345355   1.552016    Dhaka  1.698340
# 1         1.452113        0.697565   1.383714      Ctg  1.688874
# 2         1.303634       -0.524290   1.166654  Rangpur  1.673929
# 3         1.156567       -0.097977   1.017368    Dhaka  1.509736
# 4         1.119836       -0.761543   0.914576  Rangpur  1.172943

# %%
from sklearn.preprocessing import MaxAbsScaler
mas=MaxAbsScaler()

# %%
for col in x5.columns:
    if x5[col].dtype=='float64':
        x5[col]=mas.fit_transform(x5[[col]])
    else:
        continue

# %%
x5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.749527   1.000000    Dhaka  1.000000
# 1         0.983359        0.828805   0.940893      Ctg  0.997557
# 2         0.927985        0.553781   0.864664  Rangpur  0.993699
# 3         0.873136        0.649738   0.812235    Dhaka  0.951317
# 4         0.859438        0.500378   0.776136  Rangpur  0.864383
